# %%
import pandas as pd
import os 
import numpy as np

year = '2014'
month = '1'

FOLDER_PATH = '/media/christoforos/DATA/signal2vec/vectorized_sequences/{}/{}'.format(year, month)

def calculate_mean_vectors(df):
    window = 500
    array = df.values
    print(array.shape)
    array = np.reshape(array, (len(array)/window, window, 300))
    sum_of_vectors = np.sum(array, axis=1)
    print(array.shape)
    print(sum_of_vectors.shape)
    print('------------------------')
    return sum_of_vectors

en2vec = dict()
for root,dirs,files in os.walk(FOLDER_PATH):
    for f in files:
        if f.endswith(".csv"):
            print(f)
            df = pd.read_csv(FOLDER_PATH + '/' + f)
#             en2vec[f] = calculate_mean_vectors(df)
            en2vec[f] = df.values
# Out:
# Active subwoofer28.csv
# Audio amplifier17.csv
# Audio system15.csv
# Baby monitor46.csv
# Boiler2.csv
# Breadmaker16.csv
# Broadband router18.csv
# Charger47.csv
# Coffee maker36.csv
# Computer monitor14.csv
# mains.csv
# Microwave13.csv
# Mobile phone charger34.csv
# Mobile phone charger38.csv
# Oven42.csv
# Printer53.csv
# Radio37.csv
# Solar thermal pumping station3.csv
# Tablet computer charger27.csv
# Computer43.csv
# Desktop computer51.csv
# Dish washer6.csv
# Ethernet switch21.csv
# Fridge freezer12.csv
# Hair dryer39.csv
# Hair straighteners40.csv
# HTPC9.csv
# Kettle10.csv
# Laptop computer4.csv
# Light19.csv
# Light23.csv
# Light24.csv
# Light25.csv
# Light26.csv
# Light29.csv
# Light31.csv
# Light8.csv
# Television7.csv
# Toaster11.csv
# Vacuum cleaner22.csv
# Washer dryer5.csv
# Wireless phone charger32.csv
# Light33.csv
# Light35.csv
# Light44.csv
# Light45.csv
# Light48.csv
# Light49.csv
# Light50.csv

# %%
def calculate_min_max_distances(mains, aggregated):
    samples = mains.shape[0]
    distances = list()
    for i in range(samples):
        dist = np.linalg.norm(mains[i] - aggregated[i])
        distances.append(dist)
    maximum = np.max(distances)
    minimum = np.min(distances)
    mean = np.mean(distances)
    print('Max {}'.format(maximum))
    print('Min {}'.format(minimum))
    print('Mean {}'.format(mean))
    print('-----------------------')


aggregated = None
mains = en2vec['mains.csv']
for k, v in en2vec.items():
    if k is 'mains.csv':
        continue
    if aggregated is None:
        aggregated = v
    else:
        aggregated = np.add(aggregated, v)
    calculate_min_max_distances(mains, aggregated)
#     dist = np.linalg.norm(np.sum(mains, axis=0)-np.sum(aggregated, axis=0))
#     print(dist)
# Out:
# Max 15.5962643739
# Min 0.0
# Mean 4.6815822596
# -----------------------
# Max 15.5962643739
# Min 0.0
# Mean 4.6815822596
# -----------------------
# Max 23.6414018512
# Min 0.0
# Mean 4.74052062367
# -----------------------
# Max 23.6414018512
# Min 0.0
# Mean 4.74093840042
# -----------------------
# Max 23.6414018512
# Min 0.0
# Mean 4.74093840042
# -----------------------
# Max 23.6414018512
# Min 0.0
# Mean 4.74093840042
# -----------------------
# Max 23.6414018512
# Min 0.0
# Mean 4.74344968915
# -----------------------
# Max 23.6414018512
# Min 0.0
# Mean 4.75304652486
# -----------------------
# Max 23.6414018512
# Min 0.0
# Mean 4.75304652486
# -----------------------
# Max 23.6414018512
# Min 0.0
# Mean 4.75307092306
# -----------------------
# Max 23.6414018512
# Min 0.0
# Mean 4.76201374519
# -----------------------
# Max 23.6414018512
# Min 0.0
# Mean 4.76201374519
# -----------------------
# Max 23.6414018512
# Min 0.0
# Mean 4.76203855388
# -----------------------
# Max 23.6414018512
# Min 0.0
# Mean 4.76209695745
# -----------------------
# Max 23.6414018512
# Min 0.0
# Mean 4.76246965159
# -----------------------
# Max 22.0163427643
# Min 0.0
# Mean 0.595138519427
# -----------------------
# Max 26.0954864762
# Min 0.0
# Mean 1.10328328216
# -----------------------
# Max 26.0954864762
# Min 0.0
# Mean 1.10330809084
# -----------------------
# Max 26.0954864762
# Min 0.0
# Mean 1.10330809084
# -----------------------
# Max 29.2183149397
# Min 0.0
# Mean 2.30319860885
# -----------------------
# Max 29.648314486
# Min 0.0
# Mean 2.31998888527
# -----------------------
# Max 29.648314486
# Min 0.0
# Mean 2.32373299918
# -----------------------
# Max 29.648314486
# Min 0.0
# Mean 2.32373299918
# -----------------------
# Max 29.648314486
# Min 0.0
# Mean 2.32373299918
# -----------------------
# Max 31.4020177965
# Min 0.0
# Mean 2.32772249423
# -----------------------
# Max 33.0245141464
# Min 0.0
# Mean 2.74919748095
# -----------------------
# Max 33.0245141464
# Min 0.0
# Mean 2.749221577
# -----------------------
# Max 33.4953589074
# Min 0.0
# Mean 2.77824602916
# -----------------------
# Max 33.4953589074
# Min 0.0
# Mean 2.77824602916
# -----------------------
# Max 33.4953589074
# Min 0.0
# Mean 2.77825400158
# -----------------------
# Max 33.4953589074
# Min 0.0
# Mean 2.79974951058
# -----------------------
# Max 33.4953589074
# Min 0.0
# Mean 2.80094852921
# -----------------------
# Max 33.4953589074
# Min 0.0
# Mean 2.80113206608
# -----------------------
# Max 33.4953589074
# Min 0.0
# Mean 2.80113206608
# -----------------------
# Max 38.9001319986
# Min 0.0
# Mean 2.99795042713
# -----------------------
# Max 38.9001319986
# Min 0.0
# Mean 2.99797482533
# -----------------------
# Max 38.9001319986
# Min 0.0
# Mean 2.99797482533
# -----------------------
# Max 38.9001319986
# Min 0.0
# Mean 2.99797482533
# -----------------------
# Max 38.9001319986
# Min 0.0
# Mean 2.99797482533
# -----------------------
# Max 38.9001319986
# Min 0.0
# Mean 2.99797482533
# -----------------------
# Max 38.9001319986
# Min 0.0
# Mean 2.99797482533
# -----------------------
# Max 38.9001319986
# Min 0.0
# Mean 2.99797482533
# -----------------------
# Max 38.9001319986
# Min 0.0
# Mean 2.99797482533
# -----------------------
# Max 38.9001319986
# Min 0.0
# Mean 3.02602528185
# -----------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-586c4e599276> in <module>()
#      22         aggregated = v
#      23     else:
# ---> 24         aggregated = np.add(aggregated, v)
#      25     calculate_min_max_distances(mains, aggregated)
#      26 #     dist = np.linalg.norm(np.sum(mains, axis=0)-np.sum(aggregated, axis=0))
#
# KeyboardInterrupt:

# %%
# Out:
# 38.9001319986
# 0.0
