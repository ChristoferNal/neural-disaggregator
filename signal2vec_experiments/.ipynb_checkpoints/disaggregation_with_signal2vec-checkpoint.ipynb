# %%
import pandas as pd
from keras import Sequential
from keras.layers import Conv1D, Conv2D, Dense
from keras.utils import plot_model
from nilmtk import DataSet


def create_model():
    '''Creates the RNN module described in the paper
    '''
    model = Sequential()

    # 1D Conv
    model.add(Conv2D(16, 4, activation="linear", input_shape=(1, 300), padding="same", strides=1))

    # model.add(Dense(128), activation='relu')

    # # Bi-directional LSTMs
    # model.add(Bidirectional(LSTM(128, return_sequences=True, stateful=False), merge_mode='concat'))
    # model.add(Bidirectional(LSTM(256, return_sequences=False, stateful=False), merge_mode='concat'))

    # Fully Connected Layers
    model.add(Dense(128, activation='relu'))
    model.add(Dense(1, activation='linear'))

    model.compile(loss='mse', optimizer='adam')
    plot_model(model, to_file='model.png', show_shapes=True)

    return model


UK_DALE = '../../Datasets/UKDALE/ukdale.h5'
END = "1-31-2014"
START = "1-1-2014"
DEVICE = "fridge"
train_building = 1

dataset = DataSet(UK_DALE)
dataset.set_window(start=START, end=END)
elec = dataset.buildings[train_building].elec
meter = elec.submeters()[DEVICE]
meter_power = meter.power_series()
chunk = next(meter_power)
df_target = pd.DataFrame(chunk)

df = pd.read_csv('jan-2014.csv')
print('Size of features and target {} - {}'.format(len(df), len(df_target)))
# Out:
# Using TensorFlow backend.
# Size of features and target 2593733 - 362032

# %%
power = meter.power_series_all_data(sample_period=6)
# df_target = pd.DataFrame(power)
print(type(power))
print(len(power))
print(power.shape)
print(power)
mains = elec.mains()
main_power = mains.power_series(sample_period=6)
chunk = next(main_power)
df_mains = pd.DataFrame(chunk)
print(len(df_mains))
print(df_mains)
# Out:
# /home/christoforos/nilmtk/nilmtk/utils.py:393: FutureWarning: fill_method is deprecated to .resample()
# the new syntax is .resample(...).ffill(limit=20)
#   data = data.resample(**resample_kwargs)
# <class 'pandas.core.series.Series'>
# 432000
# (432000,)
# 2014-01-01 00:00:00+00:00     0.0
# 2014-01-01 00:00:06+00:00     0.0
# 2014-01-01 00:00:12+00:00     0.0
# 2014-01-01 00:00:18+00:00     0.0
# 2014-01-01 00:00:24+00:00     0.0
# 2014-01-01 00:00:30+00:00     0.0
# 2014-01-01 00:00:36+00:00     0.0
# 2014-01-01 00:00:42+00:00     0.0
# 2014-01-01 00:00:48+00:00     0.0
# 2014-01-01 00:00:54+00:00     0.0
# 2014-01-01 00:01:00+00:00    90.0
# 2014-01-01 00:01:06+00:00    91.0
# 2014-01-01 00:01:12+00:00    91.0
# 2014-01-01 00:01:18+00:00    90.0
# 2014-01-01 00:01:24+00:00    89.0
# 2014-01-01 00:01:30+00:00    90.0
# 2014-01-01 00:01:36+00:00    90.0
# 2014-01-01 00:01:42+00:00    89.0
# 2014-01-01 00:01:48+00:00    89.0
# 2014-01-01 00:01:54+00:00    89.0
# 2014-01-01 00:02:00+00:00    90.0
# 2014-01-01 00:02:06+00:00    89.0
# 2014-01-01 00:02:12+00:00    88.0
# 2014-01-01 00:02:18+00:00    88.0
# 2014-01-01 00:02:24+00:00    84.0
# 2014-01-01 00:02:30+00:00    83.0
# 2014-01-01 00:02:36+00:00    83.0
# 2014-01-01 00:02:42+00:00    83.0
# 2014-01-01 00:02:48+00:00    83.0
# 2014-01-01 00:02:54+00:00    84.0
#                              ...
# 2014-01-30 23:57:00+00:00     0.0
# 2014-01-30 23:57:06+00:00     0.0
# 2014-01-30 23:57:12+00:00     0.0
# 2014-01-30 23:57:18+00:00     0.0
# 2014-01-30 23:57:24+00:00     0.0
# 2014-01-30 23:57:30+00:00     0.0
# 2014-01-30 23:57:36+00:00     0.0
# 2014-01-30 23:57:42+00:00     0.0
# 2014-01-30 23:57:48+00:00     0.0
# 2014-01-30 23:57:54+00:00     0.0
# 2014-01-30 23:58:00+00:00     0.0
# 2014-01-30 23:58:06+00:00     0.0
# 2014-01-30 23:58:12+00:00     0.0
# 2014-01-30 23:58:18+00:00     0.0
# 2014-01-30 23:58:24+00:00     0.0
# 2014-01-30 23:58:30+00:00     0.0
# 2014-01-30 23:58:36+00:00     0.0
# 2014-01-30 23:58:42+00:00     0.0
# 2014-01-30 23:58:48+00:00     0.0
# 2014-01-30 23:58:54+00:00     0.0
# 2014-01-30 23:59:00+00:00     0.0
# 2014-01-30 23:59:06+00:00     0.0
# 2014-01-30 23:59:12+00:00     0.0
# 2014-01-30 23:59:18+00:00     0.0
# 2014-01-30 23:59:24+00:00     0.0
# 2014-01-30 23:59:30+00:00     0.0
# 2014-01-30 23:59:36+00:00     0.0
# 2014-01-30 23:59:42+00:00     0.0
# 2014-01-30 23:59:48+00:00     0.0
# 2014-01-30 23:59:54+00:00     0.0
# Name: (power, active), dtype: float64
# Found duplicate index. Keeping first value
# 432000
#                                 power
#                                active
# 2014-01-01 00:00:00+00:00         NaN
# 2014-01-01 00:00:06+00:00  450.750000
# 2014-01-01 00:00:12+00:00  450.100006
# 2014-01-01 00:00:18+00:00  448.029999
# 2014-01-01 00:00:24+00:00  445.959991
# 2014-01-01 00:00:30+00:00  449.260010
# 2014-01-01 00:00:36+00:00  446.459991
# 2014-01-01 00:00:42+00:00  448.980011
# 2014-01-01 00:00:48+00:00  989.909973
# 2014-01-01 00:00:54+00:00  561.679993
# 2014-01-01 00:01:00+00:00  549.469971
